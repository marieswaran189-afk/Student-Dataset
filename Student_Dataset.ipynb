# %%
pip install faker

# %%
from faker import Faker
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fake = Faker()
n = 250

# %%
np.random.seed(42)
n=250
data = [{
    "Student_ID": i+1,
    "Name": fake.name(),
    "Gender": np.random.choice(["Male","Female"]),
    "Department": np.random.choice(["CSE","IT","ECE"]),
    "Year": np.random.choice(["1st","2nd","3rd"]),
    "Maths": np.random.randint(40,100),
    "Science": np.random.randint(40,100),
    "English": np.random.randint(40,100),
    "Attendance": np.random.randint(50,101),
    "Internal": np.random.randint(0,26)
} for i in range(n)]

# %%
df = pd.DataFrame(data)

# %%
df["Total"] = df["Maths"] + df["Science"] + df["English"]
df["Average"] = df["Total"] / 3

# %%
print(df.head())
# Out:
#    Student_ID              Name  Gender Department Year  Maths  Science  \
# 0           1       Hannah King    Male        CSE  3rd     82       47
# 1           2  Matthew Robinson    Male        ECE  3rd     50       63
# 2           3  Crystal Randolph  Female        ECE  2nd     92       41
# 3           4    Ronald Diaz MD  Female        CSE  1st     51       97
# 4           5        Diana Carr    Male        ECE  3rd     81       67
#
#    English  Attendance  Internal  Total    Average
# 0       60          88        25    189  63.000000
# 1       92          85         7    205  68.333333
# 2       63          93         5    196  65.333333
# 3       61          93        24    209  69.666667
# 4       99          65        14    247  82.333333

# %%
df
# Out:
#      Student_ID              Name  Gender Department Year  Maths  Science  \
# 0             1       Hannah King    Male        CSE  3rd     82       47
# 1             2  Matthew Robinson    Male        ECE  3rd     50       63
# 2             3  Crystal Randolph  Female        ECE  2nd     92       41
# 3             4    Ronald Diaz MD  Female        CSE  1st     51       97
# 4             5        Diana Carr    Male        ECE  3rd     81       67
# ..          ...               ...     ...        ...  ...    ...      ...
# 245         246    Matthew Herman  Female        CSE  3rd     98       87
# 246         247     Jessica Jones    Male        CSE  1st     81       75
# 247         248        Terry Bell    Male        ECE  1st     97       96
# 248         249   William Cabrera  Female         IT  3rd     92       69
# 249         250      Pamela Davis  Female         IT  2nd     52       68
#
#      English  Attendance  Internal  Total    Average
# ...

# %%
print("\nTop Students:\n", df.nlargest(5, "Average")[["Name","Average"]])
# Out:
# Top Students:
#                Name    Average
# 247     Terry Bell  94.333333
# 211  Edwin Aguirre  93.000000
# 28   Jared Edwards  92.000000
# 232   Logan Miller  91.666667
# 38   Edward Graham  91.333333

# %%
plt.scatter(df["Attendance"], df["Average"] , color="purple", label="Students")
plt.xlabel("Attendance" , color="purple")
plt.ylabel("Average Marks", color="purple")
plt.title("Attendance vs Performance" , color="red")
plt.legend()
plt.show()

# %%
dept_counts = df['Department'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(
    dept_counts,
    labels=dept_counts.index,
    autopct='%1.1f%%',
    startangle=90
)

plt.title("Student Distribution by Department")
plt.axis('equal')  # Makes pie chart circular
plt.show()

# %%
plt.figure()
plt.hist(df["Average"], bins=10)
plt.title("Distribution of Average Marks")
plt.xlabel("Average Marks")
plt.ylabel("Frequency")
plt.show()
